# %%
# =====================================================
# Image Clustering Example using K-Means
# Example: Grouping Images Automatically
# =====================================================

# Import necessary libraries
import numpy as np
from sklearn.cluster import KMeans

# %%
# ----------------------------------------------------------
# Image Names
# (Used only for displaying results)
# ----------------------------------------------------------

image_names = [

    "dog_1.jpg","dog_2.jpg","dog_3.jpg",
    "dog_4.jpg","dog_5.jpg","dog_6.jpg",

    "cat_1.jpg","cat_2.jpg","cat_3.jpg",
    "cat_4.jpg","cat_5.jpg","cat_6.jpg",

    "car_1.jpg","car_2.jpg","car_3.jpg",
    "car_4.jpg","car_5.jpg","car_6.jpg",

    "mountain_1.jpg","mountain_2.jpg","mountain_3.jpg",
    "mountain_4.jpg","mountain_5.jpg","mountain_6.jpg",

    "unknown_1.jpg",
    "unknown_2.jpg",
    "unknown_3.jpg",
    "unknown_4.jpg",
    "unknown_5.jpg",
    "unknown_6.jpg"

]

# %%
# ----------------------------------------------------------
# Sample Image Features
#
# Suppose every image is converted into two numerical
# features:
#
# Feature 1 = Color
# Feature 2 = Texture
#
# These values are made up ONLY for demonstration.
# ----------------------------------------------------------

image_features = np.array([

# Dogs
[12,18],[14,20],[13,17],[15,19],[11,18],[16,20],

# Cats
[60,65],[62,67],[59,64],[63,66],[61,63],[60,68],

# Cars
[120,20],[118,18],[122,22],[119,19],[121,21],[123,20],

# Mountains
[200,180],[198,182],[201,179],
[203,181],[199,178],[202,183],

# Unknown Images
[250,50],     # Flower
[180,20],     # Airplane
[170,100],    # Bicycle
[90,150],     # City
[230,90],     # Burger
[180,200]     # Beach

])

# %%
# Create KMeans Model
# ----------------------------------------------------------

kmeans = KMeans(
    n_clusters=4,
    random_state=42
)

# Train the model

kmeans.fit(image_features)

# Cluster assignments

clusters = kmeans.labels_

# %%
# Display Results
# ----------------------------------------------------------

print("="*50)
print("IMAGE CLUSTERING RESULTS")
print("="*50)

for image, cluster in zip(image_names, clusters):

    print(f"{image:18} ---> Cluster {cluster}")

# ----------------------------------------------------------
# Cluster Centers
# ----------------------------------------------------------

print("\nCluster Centers")
print("-"*40)

print(kmeans.cluster_centers_)
# Out:
# ==================================================
# IMAGE CLUSTERING RESULTS
# ==================================================
# dog_1.jpg          ---> Cluster 2
# dog_2.jpg          ---> Cluster 2
# dog_3.jpg          ---> Cluster 2
# dog_4.jpg          ---> Cluster 2
# dog_5.jpg          ---> Cluster 2
# dog_6.jpg          ---> Cluster 2
# cat_1.jpg          ---> Cluster 0
# cat_2.jpg          ---> Cluster 0
# cat_3.jpg          ---> Cluster 0
# cat_4.jpg          ---> Cluster 0
# cat_5.jpg          ---> Cluster 0
# cat_6.jpg          ---> Cluster 0
# car_1.jpg          ---> Cluster 3
# car_2.jpg          ---> Cluster 3
# car_3.jpg          ---> Cluster 3
# car_4.jpg          ---> Cluster 3
# car_5.jpg          ---> Cluster 3
# car_6.jpg          ---> Cluster 3
# mountain_1.jpg     ---> Cluster 1
# mountain_2.jpg     ---> Cluster 1
# mountain_3.jpg     ---> Cluster 1
# mountain_4.jpg     ---> Cluster 1
# mountain_5.jpg     ---> Cluster 1
# mountain_6.jpg     ---> Cluster 1
# unknown_1.jpg      ---> Cluster 3
# unknown_2.jpg      ---> Cluster 3
# unknown_3.jpg      ---> Cluster 3
# unknown_4.jpg      ---> Cluster 0
# unknown_5.jpg      ---> Cluster 3
# unknown_6.jpg      ---> Cluster 1
#
# Cluster Centers
# ----------------------------------------
# [[ 65.          77.57142857]
#  [197.57142857 183.28571429]
#  [ 13.5         18.66666667]
#  [155.3         38.        ]]

# %%
# Simple Demo of Reinforcement Learning
# Import Random
# Give reward to a Robot for reaching the right goal interns of direction
import random
# Environment
goal = 5
position = 0
# Output
print(' Robot starts at postion: ', position)
while position != goal:
    # Action, Random action
    action = random.choice(['LEFT', 'RIGHT'])
    if action == "RIGHT":
        position += 1
    else:
        position = max(0, position - 1)
    # Rewards
    if position == goal:
        reward = 100
    else:
        reward = -1
    # Output the action of the robot
    print(f"Action: {action:5} position: {position} Reward: {reward}")
print("\nRobot has Reached our goal")
# Out:
#  Robot starts at postion:  0
# Action: LEFT  position: 0 Reward: -1
# Action: RIGHT position: 1 Reward: -1
# Action: RIGHT position: 2 Reward: -1
# Action: RIGHT position: 3 Reward: -1
# Action: LEFT  position: 2 Reward: -1
# Action: LEFT  position: 1 Reward: -1
# Action: RIGHT position: 2 Reward: -1
# Action: LEFT  position: 1 Reward: -1
# Action: LEFT  position: 0 Reward: -1
# Action: LEFT  position: 0 Reward: -1
# Action: RIGHT position: 1 Reward: -1
# Action: LEFT  position: 0 Reward: -1
# Action: LEFT  position: 0 Reward: -1
# Action: RIGHT position: 1 Reward: -1
# Action: RIGHT position: 2 Reward: -1
# Action: LEFT  position: 1 Reward: -1
# Action: LEFT  position: 0 Reward: -1
# Action: LEFT  position: 0 Reward: -1
# Action: LEFT  position: 0 Reward: -1
# Action: RIGHT position: 1 Reward: -1
# Action: RIGHT position: 2 Reward: -1
# Action: LEFT  position: 1 Reward: -1
# Action: LEFT  position: 0 Reward: -1
# Action: RIGHT position: 1 Reward: -1
# Action: RIGHT position: 2 Reward: -1
# Action: LEFT  position: 1 Reward: -1
# Action: LEFT  position: 0 Reward: -1
# Action: LEFT  position: 0 Reward: -1
# Action: RIGHT position: 1 Reward: -1
# Action: RIGHT position: 2 Reward: -1
# Action: LEFT  position: 1 Reward: -1
# Action: RIGHT position: 2 Reward: -1
# Action: RIGHT position: 3 Reward: -1
# Action: LEFT  position: 2 Reward: -1
# Action: RIGHT position: 3 Reward: -1
# Action: LEFT  position: 2 Reward: -1
# Action: LEFT  position: 1 Reward: -1
# Action: RIGHT position: 2 Reward: -1
# Action: RIGHT position: 3 Reward: -1
# Action: RIGHT position: 4 Reward: -1
# Action: RIGHT position: 5 Reward: 100
#
# Robot has Reached our goal

# %%
#assignment 
#create a snake game using reinforcement learning
# Simple Snake Game with Q-Learning (text-based)
import random
import numpy as np

grid_size = 6
actions = ["UP", "DOWN", "LEFT", "RIGHT"]
alpha = 0.1
gamma = 0.9
epsilon = 0.2

q_table = {}

def reset_game():
    snake = [(grid_size // 2, grid_size // 2)]
    food = (random.randrange(grid_size), random.randrange(grid_size))
    while food in snake:
        food = (random.randrange(grid_size), random.randrange(grid_size))
    direction = "RIGHT"
    return snake, food, direction

def get_state(snake, food):
    head_x, head_y = snake[0]
    food_x, food_y = food
    return (head_x, head_y, food_x, food_y)

def get_q_values(state):
    if state not in q_table:
        q_table[state] = np.zeros(len(actions))
    return q_table[state]

def move(head, action):
    x, y = head
    if action == "UP":
        return (x, y - 1)
    if action == "DOWN":
        return (x, y + 1)
    if action == "LEFT":
        return (x - 1, y)
    return (x + 1, y)

def step(snake, food, action):
    new_head = move(snake[0], action)

    # collision with wall or self
    if (
        new_head[0] < 0 or new_head[0] >= grid_size or
        new_head[1] < 0 or new_head[1] >= grid_size or
        new_head in snake
    ):
        return snake, food, -10, True

    snake = [new_head] + snake

    # eat food
    if new_head == food:
        reward = 10
        food = (random.randrange(grid_size), random.randrange(grid_size))
        while food in snake:
            food = (random.randrange(grid_size), random.randrange(grid_size))
        done = False
    else:
        snake.pop()
        reward = -0.1
        done = False

    return snake, food, reward, done

# Training
episodes = 300

for episode in range(episodes):
    snake, food, direction = reset_game()
    total_reward = 0

    for _ in range(100):
        state = get_state(snake, food)
        q_values = get_q_values(state)

        if random.random() < epsilon:
            action_idx = random.randrange(len(actions))
        else:
            action_idx = int(np.argmax(q_values))

        action = actions[action_idx]
        next_snake, next_food, reward, done = step(snake, food, action)
        next_state = get_state(next_snake, next_food)
        next_q_values = get_q_values(next_state)

        old_value = q_values[action_idx]
        next_max = np.max(next_q_values)

        q_values[action_idx] = old_value + alpha * (reward + gamma * next_max - old_value)

        snake, food = next_snake, next_food
        total_reward += reward

        if reward == -10:
            break

    if (episode + 1) % 50 == 0:
        print(f"Episode {episode + 1}: total reward = {total_reward:.2f}")

# Demo after training
snake, food, direction = reset_game()
print("\nDemo run:")
for _ in range(20):
    state = get_state(snake, food)
    action_idx = int(np.argmax(get_q_values(state)))
    action = actions[action_idx]
    snake, food, reward, done = step(snake, food, action)
    print(f"Action: {action:5} | Head: {snake[0]} | Food: {food} | Reward: {reward}")
    if reward == -10:
        print("Game over")
        break
# Out:
# Episode 50: total reward = -0.10
# Episode 100: total reward = -11.50
# Episode 150: total reward = -10.40
# Episode 200: total reward = -10.40
# Episode 250: total reward = -12.20
# Episode 300: total reward = -10.80
#
# Demo run:
# Action: LEFT  | Head: (2, 3) | Food: (0, 3) | Reward: -0.1
# Action: UP    | Head: (2, 2) | Food: (0, 3) | Reward: -0.1
# Action: DOWN  | Head: (2, 3) | Food: (0, 3) | Reward: -0.1
# Action: UP    | Head: (2, 2) | Food: (0, 3) | Reward: -0.1
# Action: DOWN  | Head: (2, 3) | Food: (0, 3) | Reward: -0.1
# Action: UP    | Head: (2, 2) | Food: (0, 3) | Reward: -0.1
# Action: DOWN  | Head: (2, 3) | Food: (0, 3) | Reward: -0.1
# Action: UP    | Head: (2, 2) | Food: (0, 3) | Reward: -0.1
# Action: DOWN  | Head: (2, 3) | Food: (0, 3) | Reward: -0.1
# Action: UP    | Head: (2, 2) | Food: (0, 3) | Reward: -0.1
# Action: DOWN  | Head: (2, 3) | Food: (0, 3) | Reward: -0.1
# Action: UP    | Head: (2, 2) | Food: (0, 3) | Reward: -0.1
# Action: DOWN  | Head: (2, 3) | Food: (0, 3) | Reward: -0.1
# Action: UP    | Head: (2, 2) | Food: (0, 3) | Reward: -0.1
# Action: DOWN  | Head: (2, 3) | Food: (0, 3) | Reward: -0.1
# Action: UP    | Head: (2, 2) | Food: (0, 3) | Reward: -0.1
# Action: DOWN  | Head: (2, 3) | Food: (0, 3) | Reward: -0.1
# Action: UP    | Head: (2, 2) | Food: (0, 3) | Reward: -0.1
# Action: DOWN  | Head: (2, 3) | Food: (0, 3) | Reward: -0.1
# Action: UP    | Head: (2, 2) | Food: (0, 3) | Reward: -0.1
